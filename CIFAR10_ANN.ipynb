# %% [markdown]
# # CIFAR10 Artificial Neural Network¶

# %%
import tensorflow as tf
import tensorflow_datasets as tfds
from tensorflow.keras import layers, optimizers, metrics, Sequential, utils
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
train_data, test_data = tfds.load('cifar10', split=['train', 'test'])
class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

# %%
def transform(elm):
    return (tf.cast(elm['image'], tf.float32) / 255, tf.one_hot(elm['label'], 10) #1-0, one-hot encoding
           )
train_validation_data = train_data.map(transform, num_parallel_calls=tf.data.AUTOTUNE)

# %%
validation_data = train_validation_data.shard(10, 9)
validation_data = validation_data.batch(64)
validation_data = validation_data.cache() 
validation_data = validation_data.prefetch(tf.data.AUTOTUNE)

# %%
train_data = train_validation_data.shard(10, 8)
for i in range(8):
    train_data = train_data.concatenate(train_validation_data.shard(10, i))
train_data = train_data.cache()
train_data = train_data.shuffle(len(train_data))
train_data = train_data.batch(64)
train_data = train_data.prefetch(tf.data.AUTOTUNE)

# %%
test_data = test_data.map(
    transform, num_parallel_calls=tf.data.AUTOTUNE)
test_data = test_data.batch(64)
test_data = test_data.cache()
test_data = test_data.prefetch(tf.data.AUTOTUNE)

# %%
test_data
# Out:
# <PrefetchDataset element_spec=(TensorSpec(shape=(None, 32, 32, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None, 10), dtype=tf.float32, name=None))>

# %%
imgs, labels = train_data.as_numpy_iterator().next()
plt.figure(figsize=(10,10)) 
for i in range(5):
    plt.subplot(1,5,i+1)
    plt.imshow(imgs[i], cmap=plt.cm.binary)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.title(class_names[np.argmax(labels[i])])
plt.show()

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=(32,32,3)),
    tf.keras.layers.Dense(320, activation='sigmoid'),
    tf.keras.layers.Dense(240, activation='sigmoid'),
    tf.keras.layers.Dense(10, activation='softmax')
])
opt = tf.keras.optimizers.SGD(learning_rate=0.02)
model.compile(optimizer=opt,
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
model.input[0]
# Out:
# <KerasTensor: shape=(32, 32, 3) dtype=float32 (created by layer 'tf.__operators__.getitem')>

# %%
history = model.fit(train_data,
    validation_data=validation_data,
    epochs=40,
         )
# Out:
# Epoch 1/40
# 704/704 [==============================] - 4s 4ms/step - loss: 2.2512 - accuracy: 0.1719 - val_loss: 2.1903 - val_accuracy: 0.1734
# Epoch 2/40
# 704/704 [==============================] - 2s 3ms/step - loss: 2.1064 - accuracy: 0.2573 - val_loss: 2.0632 - val_accuracy: 0.2502
# Epoch 3/40
# 704/704 [==============================] - 2s 3ms/step - loss: 1.9977 - accuracy: 0.2887 - val_loss: 1.9768 - val_accuracy: 0.2824
# Epoch 4/40
# 704/704 [==============================] - 2s 3ms/step - loss: 1.9372 - accuracy: 0.3113 - val_loss: 1.9333 - val_accuracy: 0.3094
# Epoch 5/40
# 704/704 [==============================] - 2s 3ms/step - loss: 1.9012 - accuracy: 0.3242 - val_loss: 1.9066 - val_accuracy: 0.3160
# Epoch 6/40
# 704/704 [==============================] - 2s 3ms/step - loss: 1.8761 - accuracy: 0.3370 - val_loss: 1.9110 - val_accuracy: 0.2988
# Epoch 7/40
# 704/704 [==============================] - 2s 3ms/step - loss: 1.8560 - accuracy: 0.3430 - val_loss: 1.8723 - val_accuracy: 0.3292
# Epoch 8/40
# 704/704 [==============================] - 2s 3ms/step - loss: 1.8381 - accuracy: 0.3509 - val_loss: 1.8545 - val_accuracy: 0.3342
# Epoch 9/40
# 704/704 [==============================] - 2s 3ms/step - loss: 1.8224 - accuracy: 0.3570 - val_loss: 1.8603 - val_accuracy: 0.3380
# Epoch 10/40
# 704/704 [==============================] - 2s 3ms/step - loss: 1.8069 - accuracy: 0.3616 - val_loss: 1.8359 - val_accuracy: 0.3430
# Epoch 11/40
# 704/704 [==============================] - 2s 3ms/step - loss: 1.7942 - accuracy: 0.3684 - val_loss: 1.8290 - val_accuracy: 0.3398
# Epoch 12/40
# 704/704 [==============================] - 2s 3ms/step - loss: 1.7810 - accuracy: 0.3724 - val_loss: 1.8079 - val_accuracy: 0.3588
# Epoch 13/40
# 704/704 [==============================] - 2s 3ms/step - loss: 1.7689 - accuracy: 0.3776 - val_loss: 1.7897 - val_accuracy: 0.3630
# Epoch 14/40
# 704/704 [==============================] - 2s 3ms/step - loss: 1.7570 - accuracy: 0.3816 - val_loss: 1.8076 - val_accuracy: 0.3478
# Epoch 15/40
# 704/704 [==============================] - 2s 3ms/step - loss: 1.7475 - accuracy: 0.3860 - val_loss: 1.7804 - val_accuracy: 0.3640
# Epoch 16/40
# 704/704 [==============================] - 2s 3ms/step - loss: 1.7351 - accuracy: 0.3890 - val_loss: 1.7673 - val_accuracy: 0.3764
# Epoch 17/40
# 704/704 [==============================] - 2s 3ms/step - loss: 1.7248 - accuracy: 0.3937 - val_loss: 1.7784 - val_accuracy: 0.3662
# Epoch 18/40
# 704/704 [==============================] - 2s 3ms/step - loss: 1.7146 - accuracy: 0.3977 - val_loss: 1.8048 - val_accuracy: 0.3522
# Epoch 19/40
# 704/704 [==============================] - 2s 3ms/step - loss: 1.7048 - accuracy: 0.4002 - val_loss: 1.8122 - val_accuracy: 0.3578
# Epoch 20/40
# 704/704 [==============================] - 2s 3ms/step - loss: 1.6935 - accuracy: 0.4044 - val_loss: 1.7911 - val_accuracy: 0.3708
# Epoch 21/40
# 704/704 [==============================] - 2s 3ms/step - loss: 1.6832 - accuracy: 0.4081 - val_loss: 1.7331 - val_accuracy: 0.3774
# Epoch 22/40
# 704/704 [==============================] - 2s 3ms/step - loss: 1.6741 - accuracy: 0.4130 - val_loss: 1.7248 - val_accuracy: 0.3868
# Epoch 23/40
# 704/704 [==============================] - 2s 3ms/step - loss: 1.6643 - accuracy: 0.4157 - val_loss: 1.7265 - val_accuracy: 0.3796
# Epoch 24/40
# 704/704 [==============================] - 2s 3ms/step - loss: 1.6536 - accuracy: 0.4187 - val_loss: 1.7169 - val_accuracy: 0.3848
# Epoch 25/40
# 704/704 [==============================] - 2s 3ms/step - loss: 1.6447 - accuracy: 0.4223 - val_loss: 1.7624 - val_accuracy: 0.3726
# Epoch 26/40
# 704/704 [==============================] - 2s 3ms/step - loss: 1.6347 - accuracy: 0.4266 - val_loss: 1.6879 - val_accuracy: 0.4036
# Epoch 27/40
# 704/704 [==============================] - 2s 3ms/step - loss: 1.6258 - accuracy: 0.4283 - val_loss: 1.7004 - val_accuracy: 0.3926
# Epoch 28/40
# 704/704 [==============================] - 2s 3ms/step - loss: 1.6167 - accuracy: 0.4329 - val_loss: 1.7037 - val_accuracy: 0.3884
# Epoch 29/40
# 704/704 [==============================] - 2s 3ms/step - loss: 1.6073 - accuracy: 0.4358 - val_loss: 1.6692 - val_accuracy: 0.3936
# Epoch 30/40
# 704/704 [==============================] - 2s 3ms/step - loss: 1.5991 - accuracy: 0.4374 - val_loss: 1.6711 - val_accuracy: 0.3908
# Epoch 31/40
# 704/704 [==============================] - 2s 3ms/step - loss: 1.5917 - accuracy: 0.4418 - val_loss: 1.6746 - val_accuracy: 0.3918
# Epoch 32/40
# 704/704 [==============================] - 2s 3ms/step - loss: 1.5823 - accuracy: 0.4433 - val_loss: 1.6842 - val_accuracy: 0.3856
# Epoch 33/40
# 704/704 [==============================] - 2s 3ms/step - loss: 1.5753 - accuracy: 0.4475 - val_loss: 1.6604 - val_accuracy: 0.3886
# Epoch 34/40
# 704/704 [==============================] - 2s 3ms/step - loss: 1.5675 - accuracy: 0.4497 - val_loss: 1.6671 - val_accuracy: 0.4028
# Epoch 35/40
# 704/704 [==============================] - 2s 3ms/step - loss: 1.5597 - accuracy: 0.4500 - val_loss: 1.6327 - val_accuracy: 0.4036
# Epoch 36/40
# 704/704 [==============================] - 2s 3ms/step - loss: 1.5511 - accuracy: 0.4547 - val_loss: 1.6325 - val_accuracy: 0.4166
# Epoch 37/40
# 704/704 [==============================] - 2s 3ms/step - loss: 1.5456 - accuracy: 0.4553 - val_loss: 1.6977 - val_accuracy: 0.3824
# Epoch 38/40
# 704/704 [==============================] - 2s 3ms/step - loss: 1.5364 - accuracy: 0.4626 - val_loss: 1.7280 - val_accuracy: 0.3870
# Epoch 39/40
# 704/704 [==============================] - 2s 3ms/step - loss: 1.5303 - accuracy: 0.4619 - val_loss: 1.7993 - val_accuracy: 0.3634
# Epoch 40/40
# 704/704 [==============================] - 2s 3ms/step - loss: 1.5229 - accuracy: 0.4640 - val_loss: 1.6589 - val_accuracy: 0.4066

# %%
plt.plot(range(len(history.history['accuracy'])), history.history['accuracy'], 'ro', label='Training acc')
plt.plot(range(len(history.history['accuracy'])), history.history['val_accuracy'], 'b', label='Validation acc')
plt.title('Training & Validation acc')
plt.legend()
plt.figure()
plt.show()

# %%
model.evaluate(test_data, return_dict=True)
# Out:
# 157/157 [==============================] - 1s 4ms/step - loss: 1.6326 - accuracy: 0.4210
# {'loss': 1.6326308250427246, 'accuracy': 0.42100000381469727}
